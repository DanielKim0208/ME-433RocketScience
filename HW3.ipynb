# %% [markdown]
# # ME-433 Rocket Science
# ## HW 3
# ### Oblique shock calculator

# %% [markdown]
# A python function which :
#
# +  takes in the **incoming Mach number(M_1), ratio of specific heats(gamma), and turning angle(theta)**
# +  outputs the corresponding **pressure ratio(P), temperature ratio(T), and outgoing Mach number(M_2) solution**
#
# for a calorically perfect gas(CPG) in the case of **supersonic oblique Shock**

# %%
import numpy as np

def Theta_beta(M,beta, gamma): 
    # This function finds the tan(theta) value as the function of Mach number and beta angle using the theta-beta relationship 
    tanTheta = (2 * (1/np.tan(beta))) * ((M * M * np.sin(beta) * np.sin(beta)) - 1)/(M * M * (gamma * np.cos(2*beta))+2)
    return np.arctan(tanTheta)




def machCalc(M_1,gamma, theta): 
    #Function that takes incoming Mach Number(M_1), ratio of specific heats(gamma), and turning angle(theta) 
    #to return pressure ratio(P), temperature ratio(T), and outgoing Mach number(M_2)
    if M_1 < 1: 
        return ("ERROR : The Oblique shock calculator only works in the case of sonic or supersonic shock")

    elif theta == 0: 
        #If theta == 0, this becomes the normal shock case
        P_n = 1 + ((2* gamma)/(gamma + 1)) * ((M_1 * M_1 - 1))
        rho_n = ((gamma + 1) * M_1 * M_1) / (2 + (gamma - 1) * (M_1 * M_1))
        T_n = P_n * rho_n
        M_2_squared_n = (1 + ((gamma-1)/2)*M_1*M_1)/ ((gamma * M_1 * M_1) - ((gamma-1)/2))
        M_2_n = np.sqrt(M_2_squared_n)
        return P_n, T_n, M_2_n
        
    elif theta != 0: 
        #If theta != 0, this becomes oblique shock case 
        P_o = 
        T_o = 
        M_2_o = 
        return P_o, T_o, M_2_o
